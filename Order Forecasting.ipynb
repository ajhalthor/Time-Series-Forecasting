# %% [markdown]
# **Indian Restaurant datatset**: https://www.kaggle.com/henslersoftware/19560-indian-takeaway-orders
#
#
# **Objective**: We want to forecast out order volume for staffing
#
# **Notes**
# - Find the number of daily orders
# - Using pandasql since it'll be as close to what you'd be doing at work (working with SQL)

# %%
#!pip3 install pandasql

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from xgboost import XGBRegressor

# %%
from pandasql import sqldf
pysqldf = lambda q: sqldf(q, globals())

# %%
orders = pd.read_csv('data/restaurant-1-orders.csv')
orders.columns = ['number', 'timestamp', 'item', 'quantity', 'price', 'total_products_in_cart']

# %%
orders.sample(2)
# Out:
#        number         timestamp                item  quantity  price  \
# 609     15546  28/06/2019 20:23       Mango Chutney         1   0.50
# 37927    3863  01/12/2016 19:40  Special Fried Rice         1   3.95
#
#        total_products_in_cart
# 609                         7
# 37927                       4

# %%
orders['date'] = pd.to_datetime(orders['timestamp'].str[:10])

# %%
orders.sample(2)
# Out:
#        number         timestamp                   item  quantity  price  \
# 60888    7707  09/12/2017 17:26                  Korma         1   8.95
# 71912    8314  26/01/2018 19:25  Chicken Tikka Biryani         1  10.95
#
#        total_products_in_cart       date
# 60888                       6 2017-09-12
# 71912                       7 2018-01-26

# %%
print(f"Total number of orders in dataset: {orders['number'].nunique()}")
# Out:
# Total number of orders in dataset: 13397

# %%
def load_query(path):
    with open(path) as file:
        return file.read()

# %% [markdown]
# ### Case 1: Direct Multistep Forecasting

# %%
query = load_query('queries/daily_orders.sql')
daily_orders = pysqldf(query)

# %%
daily_orders.sample(2)
# Out:
#            date  num_orders
# 304  2017-02-02           2
# 477  2017-07-26           6

# %%
import logging
logging.getLogger().setLevel(logging.CRITICAL) # Prevent the matplotlib infos on categorical x-axis, removable

# %%
plt.rcParams.update({'figure.figsize': (17, 3), 'figure.dpi':300})
fig, ax = plt.subplots()
sns.lineplot(data=daily_orders.tail(50), x='date', y='num_orders')
plt.grid(linestyle='-', linewidth=0.3)
ax.tick_params(axis='x', rotation=90)

# %% [markdown]
# Too less orders daily to bother forecasting. Let's look at weekly order volume instead

# %%
query = load_query('queries/weekly_orders.sql')
weekly_orders = pysqldf(query)

# %%
weekly_orders.sample(2)
# Out:
#            week  num_orders
# 136  2018-08-13          94
# 2    2015-08-03           3

# %%
plt.rcParams.update({'figure.figsize': (17, 3), 'figure.dpi':300})
fig, ax = plt.subplots()
sns.lineplot(data=weekly_orders.tail(50), x='week', y='num_orders')
plt.grid(linestyle='-', linewidth=0.3)
ax.tick_params(axis='x', rotation=90)

# %%
query = load_query('queries/base.sql')
df = pysqldf(query)
df.to_csv('csvs/dataset.csv')

# %%
df.sample(3)
# Out:
#            week  order_count_7_day  order_count_30_day  label
# 131  2018-08-13                 99                 362     94
# 30   2016-09-05                 38                 174     35
# 38   2016-10-31                 55                 256     21

# %%
features = ['order_count_7_day', 'order_count_30_day']
label = 'label'
test_df = df[df['week'] >= '2019-06-01']
train_df = df[df['week'] < '2019-06-01']
X_train, y_train = train_df[features], train_df[label]
X_test, y_test = test_df[features], test_df[label]

# %%
reg = XGBRegressor(n_estimators=500, learning_rate=0.01)
reg.fit(X_train, 
        y_train,
        eval_set=[(X_train, y_train), (X_test, y_test)],
        eval_metric='mae')
# Out:
# [0]	validation_0-mae:68.79894	validation_1-mae:72.73835
# [1]	validation_0-mae:68.12782	validation_1-mae:72.12848
# [2]	validation_0-mae:67.46322	validation_1-mae:71.52456
# [3]	validation_0-mae:66.80495	validation_1-mae:70.89914
# [4]	validation_0-mae:66.15327	validation_1-mae:70.30690
# [5]	validation_0-mae:65.50797	validation_1-mae:69.72041
# [6]	validation_0-mae:64.86885	validation_1-mae:69.11307
# [7]	validation_0-mae:64.23607	validation_1-mae:68.53793
# [8]	validation_0-mae:63.60947	validation_1-mae:67.96839
# [9]	validation_0-mae:62.98890	validation_1-mae:67.37856
# [10]	validation_0-mae:62.37450	validation_1-mae:66.82005
# [11]	validation_0-mae:61.76610	validation_1-mae:66.26696
# [12]	validation_0-mae:61.16366	validation_1-mae:65.71924
# [13]	validation_0-mae:60.56696	validation_1-mae:65.16515
# [14]	validation_0-mae:59.97624	validation_1-mae:64.62994
# [15]	validation_0-mae:59.39127	validation_1-mae:64.09995
# [16]	validation_0-mae:58.81189	validation_1-mae:63.60182
# [17]	validation_0-mae:58.23829	validation_1-mae:63.08211
# [18]	validation_0-mae:57.67031	validation_1-mae:62.56745
# [19]	validation_0-mae:57.10777	validation_1-mae:62.08374
# [20]	validation_0-mae:56.55079	validation_1-mae:61.57907
# [21]	validation_0-mae:55.99930	validation_1-mae:61.07930
# [22]	validation_0-mae:55.45513	validation_1-mae:60.59889
# [23]	validation_0-mae:54.91450	validation_1-mae:60.14642
# [24]	validation_0-mae:54.38087	validation_1-mae:59.67536
# [25]	validation_0-mae:53.85216	validation_1-mae:59.19471
# [26]	validation_0-mae:53.32889	validation_1-mae:58.73287
# [27]	validation_0-mae:52.80906	validation_1-mae:58.29797
# [28]	validation_0-mae:52.29594	validation_1-mae:57.84513
# [29]	validation_0-mae:51.78754	validation_1-mae:57.38285
# [30]	validation_0-mae:51.28276	validation_1-mae:56.96068
# [31]	validation_0-mae:50.78449	validation_1-mae:56.52106
# [32]	validation_0-mae:50.29107	validation_1-mae:56.08573
# [33]	validation_0-mae:49.80250	validation_1-mae:55.65467
# [34]	validation_0-mae:49.31679	validation_1-mae:55.23701
# [35]	validation_0-mae:48.83769	validation_1-mae:54.81440
# [36]	validation_0-mae:48.36325	validation_1-mae:54.39591
# [37]	validation_0-mae:47.89342	validation_1-mae:53.98152
# [38]	validation_0-mae:47.42650	validation_1-mae:53.57262
# [39]	validation_0-mae:46.96579	validation_1-mae:53.16629
# [40]	validation_0-mae:46.50970	validation_1-mae:52.75677
# [41]	validation_0-mae:46.05803	validation_1-mae:52.35744
# [42]	validation_0-mae:45.60921	validation_1-mae:51.94620
# [43]	validation_0-mae:45.17337	validation_1-mae:51.54773
# [44]	validation_0-mae:44.74150	validation_1-mae:51.15996
# [45]	validation_0-mae:44.31488	validation_1-mae:50.76913
# [46]	validation_0-mae:43.89044	validation_1-mae:50.38211
# [47]	validation_0-mae:43.46798	validation_1-mae:49.99716
# [48]	validation_0-mae:43.05840	validation_1-mae:49.63235
# [49]	validation_0-mae:42.65503	validation_1-mae:49.25644
# [50]	validation_0-mae:42.25111	validation_1-mae:48.87605
# [51]	validation_0-mae:41.85719	validation_1-mae:48.52061
# [52]	validation_0-mae:41.46394	validation_1-mae:48.15512
# [53]	validation_0-mae:41.07019	validation_1-mae:47.79993
# [54]	validation_0-mae:40.68760	validation_1-mae:47.45458
# [55]	validation_0-mae:40.30872	validation_1-mae:47.11258
# [56]	validation_0-mae:39.93663	validation_1-mae:46.77438
# [57]	validation_0-mae:39.56175	validation_1-mae:46.42633
# [58]	validation_0-mae:39.20124	validation_1-mae:46.17950
# [59]	validation_0-mae:38.84422	validation_1-mae:45.98125
# [60]	validation_0-mae:38.48263	validation_1-mae:45.75640
# [61]	validation_0-mae:38.12621	validation_1-mae:45.54353
# [62]	validation_0-mae:37.77782	validation_1-mae:45.33540
# [63]	validation_0-mae:37.43664	validation_1-mae:45.14471
# [64]	validation_0-mae:37.09080	validation_1-mae:44.92838
# [65]	validation_0-mae:36.75617	validation_1-mae:44.74138
# [66]	validation_0-mae:36.41801	validation_1-mae:44.53854
# [67]	validation_0-mae:36.08593	validation_1-mae:44.34017
# [68]	validation_0-mae:35.75732	validation_1-mae:44.13779
# [69]	validation_0-mae:35.42713	validation_1-mae:43.92613
# [70]	validation_0-mae:35.10618	validation_1-mae:43.74795
# [71]	validation_0-mae:34.78522	validation_1-mae:43.55475
# [72]	validation_0-mae:34.46878	validation_1-mae:43.36565
# [73]	validation_0-mae:34.15270	validation_1-mae:43.17617
# [74]	validation_0-mae:33.84391	validation_1-mae:43.00469
# [75]	validation_0-mae:33.53650	validation_1-mae:42.82093
# [76]	validation_0-mae:33.22853	validation_1-mae:42.63044
# [77]	validation_0-mae:32.93156	validation_1-mae:42.46390
# [78]	validation_0-mae:32.63711	validation_1-mae:42.26582
# [79]	validation_0-mae:32.34416	validation_1-mae:42.08709
# [80]	validation_0-mae:32.05782	validation_1-mae:41.92531
# [81]	validation_0-mae:31.76782	validation_1-mae:41.76745
# [82]	validation_0-mae:31.48005	validation_1-mae:41.61252
# [83]	validation_0-mae:31.19644	validation_1-mae:41.45762
# [84]	validation_0-mae:30.91494	validation_1-mae:41.30558
# [85]	validation_0-mae:30.63597	validation_1-mae:41.15358
# [86]	validation_0-mae:30.36019	validation_1-mae:40.99174
# [87]	validation_0-mae:30.08732	validation_1-mae:40.84265
# [88]	validation_0-mae:29.81609	validation_1-mae:40.70876
# [89]	validation_0-mae:29.54800	validation_1-mae:40.55004
# [90]	validation_0-mae:29.28192	validation_1-mae:40.41867
# [91]	validation_0-mae:29.01941	validation_1-mae:40.27506
# [92]	validation_0-mae:28.76548	validation_1-mae:40.10298
# [93]	validation_0-mae:28.51246	validation_1-mae:39.95999
# [94]	validation_0-mae:28.26743	validation_1-mae:39.79043
# [95]	validation_0-mae:28.01865	validation_1-mae:39.65012
# [96]	validation_0-mae:27.77520	validation_1-mae:39.48285
# [97]	validation_0-mae:27.53334	validation_1-mae:39.34518
# [98]	validation_0-mae:27.29166	validation_1-mae:39.20881
# [99]	validation_0-mae:27.05804	validation_1-mae:39.04792
# [100]	validation_0-mae:26.82453	validation_1-mae:38.91413
# [101]	validation_0-mae:26.59812	validation_1-mae:38.77795
# [102]	validation_0-mae:26.37528	validation_1-mae:38.64447
# [103]	validation_0-mae:26.14907	validation_1-mae:38.52600
# [104]	validation_0-mae:25.93227	validation_1-mae:38.38195
# [105]	validation_0-mae:25.71031	validation_1-mae:38.26568
# [106]	validation_0-mae:25.49598	validation_1-mae:38.12847
# [107]	validation_0-mae:25.28323	validation_1-mae:38.01451
# [108]	validation_0-mae:25.07653	validation_1-mae:37.87410
# [109]	validation_0-mae:24.87090	validation_1-mae:37.74948
# [110]	validation_0-mae:24.66589	validation_1-mae:37.62681
# [111]	validation_0-mae:24.46580	validation_1-mae:37.51882
# [112]	validation_0-mae:24.26760	validation_1-mae:37.41184
# [113]	validation_0-mae:24.06838	validation_1-mae:37.29720
# [114]	validation_0-mae:23.87686	validation_1-mae:37.18595
# [115]	validation_0-mae:23.68176	validation_1-mae:37.09705
# [116]	validation_0-mae:23.49481	validation_1-mae:36.97352
# [117]	validation_0-mae:23.31167	validation_1-mae:36.85596
# [118]	validation_0-mae:23.13191	validation_1-mae:36.71979
# [119]	validation_0-mae:22.94684	validation_1-mae:36.63338
# [120]	validation_0-mae:22.76773	validation_1-mae:36.52964
# [121]	validation_0-mae:22.59355	validation_1-mae:36.42704
# [122]	validation_0-mae:22.41202	validation_1-mae:36.35146
# [123]	validation_0-mae:22.23273	validation_1-mae:36.26854
# [124]	validation_0-mae:22.06375	validation_1-mae:36.15678
# [125]	validation_0-mae:21.88849	validation_1-mae:36.07560
# [126]	validation_0-mae:21.72231	validation_1-mae:35.96626
# [127]	validation_0-mae:21.54849	validation_1-mae:35.89183
# [128]	validation_0-mae:21.37626	validation_1-mae:35.81641
# [129]	validation_0-mae:21.21379	validation_1-mae:35.71671
# [130]	validation_0-mae:21.05248	validation_1-mae:35.61792
# [131]	validation_0-mae:20.88400	validation_1-mae:35.54262
# [132]	validation_0-mae:20.72016	validation_1-mae:35.47928
# [133]	validation_0-mae:20.56270	validation_1-mae:35.38351
# [134]	validation_0-mae:20.40197	validation_1-mae:35.30970
# [135]	validation_0-mae:20.24558	validation_1-mae:35.24833
# [136]	validation_0-mae:20.09218	validation_1-mae:35.15108
# [137]	validation_0-mae:19.94122	validation_1-mae:35.08293
# [138]	validation_0-mae:19.79382	validation_1-mae:35.02250
# [139]	validation_0-mae:19.64468	validation_1-mae:34.96686
# [140]	validation_0-mae:19.50078	validation_1-mae:34.89241
# [141]	validation_0-mae:19.35465	validation_1-mae:34.84597
# [142]	validation_0-mae:19.21301	validation_1-mae:34.77283
# [143]	validation_0-mae:19.07304	validation_1-mae:34.67632
# [144]	validation_0-mae:18.93494	validation_1-mae:34.60605
# [145]	validation_0-mae:18.79677	validation_1-mae:34.56417
# [146]	validation_0-mae:18.66344	validation_1-mae:34.47000
# [147]	validation_0-mae:18.53014	validation_1-mae:34.40190
# [148]	validation_0-mae:18.40113	validation_1-mae:34.33145
# [149]	validation_0-mae:18.26818	validation_1-mae:34.28966
# [150]	validation_0-mae:18.14343	validation_1-mae:34.22350
# [151]	validation_0-mae:18.01693	validation_1-mae:34.13347
# [152]	validation_0-mae:17.89416	validation_1-mae:34.06844
# [153]	validation_0-mae:17.77327	validation_1-mae:34.01891
# [154]	validation_0-mae:17.65218	validation_1-mae:33.92647
# [155]	validation_0-mae:17.53241	validation_1-mae:33.85498
# [156]	validation_0-mae:17.41430	validation_1-mae:33.77951
# [157]	validation_0-mae:17.29526	validation_1-mae:33.73865
# [158]	validation_0-mae:17.18185	validation_1-mae:33.65255
# [159]	validation_0-mae:17.06928	validation_1-mae:33.58545
# [160]	validation_0-mae:16.95647	validation_1-mae:33.53713
# [161]	validation_0-mae:16.84583	validation_1-mae:33.47117
# [162]	validation_0-mae:16.73993	validation_1-mae:33.40929
# [163]	validation_0-mae:16.63079	validation_1-mae:33.32796
# [164]	validation_0-mae:16.52401	validation_1-mae:33.25775
# [165]	validation_0-mae:16.42048	validation_1-mae:33.20083
# [166]	validation_0-mae:16.30963	validation_1-mae:33.11608
# [167]	validation_0-mae:16.20556	validation_1-mae:33.06139
# [168]	validation_0-mae:16.10164	validation_1-mae:33.01152
# [169]	validation_0-mae:16.00075	validation_1-mae:32.95598
# [170]	validation_0-mae:15.89258	validation_1-mae:32.90477
# [171]	validation_0-mae:15.79496	validation_1-mae:32.86864
# [172]	validation_0-mae:15.69936	validation_1-mae:32.82717
# [173]	validation_0-mae:15.59868	validation_1-mae:32.78682
# [174]	validation_0-mae:15.50442	validation_1-mae:32.74901
# [175]	validation_0-mae:15.40960	validation_1-mae:32.69369
# [176]	validation_0-mae:15.31134	validation_1-mae:32.65447
# [177]	validation_0-mae:15.22078	validation_1-mae:32.62451
# [178]	validation_0-mae:15.12788	validation_1-mae:32.57233
# [179]	validation_0-mae:15.03710	validation_1-mae:32.52059
# [180]	validation_0-mae:14.94491	validation_1-mae:32.49744
# [181]	validation_0-mae:14.85355	validation_1-mae:32.47448
# [182]	validation_0-mae:14.76356	validation_1-mae:32.45171
# [183]	validation_0-mae:14.67380	validation_1-mae:32.42913
# [184]	validation_0-mae:14.58334	validation_1-mae:32.39268
# [185]	validation_0-mae:14.49753	validation_1-mae:32.35884
# [186]	validation_0-mae:14.41239	validation_1-mae:32.34467
# [187]	validation_0-mae:14.32634	validation_1-mae:32.33065
# [188]	validation_0-mae:14.24183	validation_1-mae:32.29470
# [189]	validation_0-mae:14.15653	validation_1-mae:32.25835
# [190]	validation_0-mae:14.07326	validation_1-mae:32.21752
# [191]	validation_0-mae:13.98999	validation_1-mae:32.18189
# [192]	validation_0-mae:13.91043	validation_1-mae:32.16923
# [193]	validation_0-mae:13.83130	validation_1-mae:32.13847
# [194]	validation_0-mae:13.75216	validation_1-mae:32.10381
# [195]	validation_0-mae:13.67371	validation_1-mae:32.06949
# [196]	validation_0-mae:13.59619	validation_1-mae:32.03550
# [197]	validation_0-mae:13.52135	validation_1-mae:32.02396
# [198]	validation_0-mae:13.44475	validation_1-mae:31.99735
# [199]	validation_0-mae:13.37137	validation_1-mae:31.98417
# [200]	validation_0-mae:13.29909	validation_1-mae:31.95687
# [201]	validation_0-mae:13.22701	validation_1-mae:31.92758
# [202]	validation_0-mae:13.15504	validation_1-mae:31.89409
# [203]	validation_0-mae:13.08469	validation_1-mae:31.86762
# [204]	validation_0-mae:13.01455	validation_1-mae:31.83475
# [205]	validation_0-mae:12.94591	validation_1-mae:31.80884
# [206]	validation_0-mae:12.87336	validation_1-mae:31.77537
# [207]	validation_0-mae:12.80143	validation_1-mae:31.74219
# [208]	validation_0-mae:12.73330	validation_1-mae:31.74300
# [209]	validation_0-mae:12.66458	validation_1-mae:31.71558
# [210]	validation_0-mae:12.59685	validation_1-mae:31.71993
# [211]	validation_0-mae:12.52979	validation_1-mae:31.69301
# [212]	validation_0-mae:12.46331	validation_1-mae:31.66635
# [213]	validation_0-mae:12.39896	validation_1-mae:31.64712
# [214]	validation_0-mae:12.33648	validation_1-mae:31.64877
# [215]	validation_0-mae:12.27135	validation_1-mae:31.62284
# [216]	validation_0-mae:12.20819	validation_1-mae:31.59716
# [217]	validation_0-mae:12.14705	validation_1-mae:31.60535
# [218]	validation_0-mae:12.08517	validation_1-mae:31.57409
# [219]	validation_0-mae:12.02238	validation_1-mae:31.54030
# [220]	validation_0-mae:11.95968	validation_1-mae:31.49864
# [221]	validation_0-mae:11.90061	validation_1-mae:31.47754
# [222]	validation_0-mae:11.84177	validation_1-mae:31.46016
# [223]	validation_0-mae:11.78429	validation_1-mae:31.42789
# [224]	validation_0-mae:11.72728	validation_1-mae:31.40743
# [225]	validation_0-mae:11.67382	validation_1-mae:31.37570
# [226]	validation_0-mae:11.61722	validation_1-mae:31.35561
# [227]	validation_0-mae:11.56310	validation_1-mae:31.32443
# [228]	validation_0-mae:11.50973	validation_1-mae:31.29351
# [229]	validation_0-mae:11.45322	validation_1-mae:31.28843
# [230]	validation_0-mae:11.39712	validation_1-mae:31.27413
# [231]	validation_0-mae:11.34493	validation_1-mae:31.25848
# [232]	validation_0-mae:11.29421	validation_1-mae:31.23191
# [233]	validation_0-mae:11.23941	validation_1-mae:31.21954
# [234]	validation_0-mae:11.18904	validation_1-mae:31.19940
# [235]	validation_0-mae:11.13507	validation_1-mae:31.18726
# [236]	validation_0-mae:11.08760	validation_1-mae:31.16087
# [237]	validation_0-mae:11.03442	validation_1-mae:31.14901
# [238]	validation_0-mae:10.98769	validation_1-mae:31.12168
# [239]	validation_0-mae:10.93450	validation_1-mae:31.10500
# [240]	validation_0-mae:10.88854	validation_1-mae:31.07662
# [241]	validation_0-mae:10.84223	validation_1-mae:31.06047
# [242]	validation_0-mae:10.79846	validation_1-mae:31.02682
# [243]	validation_0-mae:10.74673	validation_1-mae:31.00888
# [244]	validation_0-mae:10.70272	validation_1-mae:30.98147
# [245]	validation_0-mae:10.65902	validation_1-mae:30.96291
# [246]	validation_0-mae:10.61687	validation_1-mae:30.93041
# [247]	validation_0-mae:10.57474	validation_1-mae:30.91101
# [248]	validation_0-mae:10.52626	validation_1-mae:30.90511
# [249]	validation_0-mae:10.48501	validation_1-mae:30.87966
# [250]	validation_0-mae:10.44548	validation_1-mae:30.87350
# [251]	validation_0-mae:10.40215	validation_1-mae:30.86319
# [252]	validation_0-mae:10.36072	validation_1-mae:30.87056
# [253]	validation_0-mae:10.31714	validation_1-mae:30.88322
# [254]	validation_0-mae:10.27800	validation_1-mae:30.89008
# [255]	validation_0-mae:10.23371	validation_1-mae:30.87146
# [256]	validation_0-mae:10.19580	validation_1-mae:30.87557
# [257]	validation_0-mae:10.15940	validation_1-mae:30.86295
# [258]	validation_0-mae:10.11814	validation_1-mae:30.84482
# [259]	validation_0-mae:10.07762	validation_1-mae:30.85769
# [260]	validation_0-mae:10.03765	validation_1-mae:30.83985
# [261]	validation_0-mae:9.99899	validation_1-mae:30.85273
# [262]	validation_0-mae:9.96000	validation_1-mae:30.83763
# [263]	validation_0-mae:9.92419	validation_1-mae:30.81517
# [264]	validation_0-mae:9.88552	validation_1-mae:30.80926
# [265]	validation_0-mae:9.85060	validation_1-mae:30.78715
# [266]	validation_0-mae:9.81360	validation_1-mae:30.77264
# [267]	validation_0-mae:9.77196	validation_1-mae:30.77945
# [268]	validation_0-mae:9.73632	validation_1-mae:30.77958
# [269]	validation_0-mae:9.70022	validation_1-mae:30.76547
# [270]	validation_0-mae:9.66104	validation_1-mae:30.77472
# [271]	validation_0-mae:9.62079	validation_1-mae:30.78252
# [272]	validation_0-mae:9.58574	validation_1-mae:30.76376
# [273]	validation_0-mae:9.54719	validation_1-mae:30.77205
# [274]	validation_0-mae:9.51064	validation_1-mae:30.77365
# [275]	validation_0-mae:9.47740	validation_1-mae:30.75658
# [276]	validation_0-mae:9.44042	validation_1-mae:30.75828
# [277]	validation_0-mae:9.40815	validation_1-mae:30.74616
# [278]	validation_0-mae:9.37137	validation_1-mae:30.74665
# [279]	validation_0-mae:9.34151	validation_1-mae:30.74474
# [280]	validation_0-mae:9.30521	validation_1-mae:30.74472
# [281]	validation_0-mae:9.27665	validation_1-mae:30.72756
# [282]	validation_0-mae:9.24079	validation_1-mae:30.72841
# [283]	validation_0-mae:9.20960	validation_1-mae:30.71258
# [284]	validation_0-mae:9.17484	validation_1-mae:30.71287
# [285]	validation_0-mae:9.14829	validation_1-mae:30.69631
# [286]	validation_0-mae:9.11327	validation_1-mae:30.69511
# [287]	validation_0-mae:9.08013	validation_1-mae:30.69747
# [288]	validation_0-mae:9.05462	validation_1-mae:30.68137
# [289]	validation_0-mae:9.02031	validation_1-mae:30.68040
# [290]	validation_0-mae:8.99476	validation_1-mae:30.67139
# [291]	validation_0-mae:8.96982	validation_1-mae:30.65571
# [292]	validation_0-mae:8.93634	validation_1-mae:30.65611
# [293]	validation_0-mae:8.90444	validation_1-mae:30.65788
# [294]	validation_0-mae:8.87966	validation_1-mae:30.64931
# [295]	validation_0-mae:8.85540	validation_1-mae:30.63399
# [296]	validation_0-mae:8.82418	validation_1-mae:30.63466
# [297]	validation_0-mae:8.79516	validation_1-mae:30.63337
# [298]	validation_0-mae:8.77065	validation_1-mae:30.62850
# [299]	validation_0-mae:8.74594	validation_1-mae:30.62148
# [300]	validation_0-mae:8.71531	validation_1-mae:30.62154
# [301]	validation_0-mae:8.69070	validation_1-mae:30.61323
# [302]	validation_0-mae:8.66767	validation_1-mae:30.60568
# [303]	validation_0-mae:8.64519	validation_1-mae:30.60015
# [304]	validation_0-mae:8.62244	validation_1-mae:30.59241
# [305]	validation_0-mae:8.59961	validation_1-mae:30.58457
# [306]	validation_0-mae:8.57863	validation_1-mae:30.57972
# [307]	validation_0-mae:8.55732	validation_1-mae:30.57266
# [308]	validation_0-mae:8.53467	validation_1-mae:30.55974
# [309]	validation_0-mae:8.51316	validation_1-mae:30.55285
# [310]	validation_0-mae:8.49183	validation_1-mae:30.54530
# [311]	validation_0-mae:8.46652	validation_1-mae:30.53854
# [312]	validation_0-mae:8.44486	validation_1-mae:30.52992
# [313]	validation_0-mae:8.42460	validation_1-mae:30.52269
# [314]	validation_0-mae:8.39968	validation_1-mae:30.51625
# [315]	validation_0-mae:8.37883	validation_1-mae:30.50960
# [316]	validation_0-mae:8.35449	validation_1-mae:30.50336
# [317]	validation_0-mae:8.33437	validation_1-mae:30.49535
# [318]	validation_0-mae:8.31426	validation_1-mae:30.48936
# [319]	validation_0-mae:8.29493	validation_1-mae:30.48259
# [320]	validation_0-mae:8.27501	validation_1-mae:30.47648
# [321]	validation_0-mae:8.25576	validation_1-mae:30.47108
# [322]	validation_0-mae:8.23700	validation_1-mae:30.46574
# [323]	validation_0-mae:8.21841	validation_1-mae:30.46104
# [324]	validation_0-mae:8.20010	validation_1-mae:30.45462
# [325]	validation_0-mae:8.18199	validation_1-mae:30.44952
# [326]	validation_0-mae:8.16298	validation_1-mae:30.44542
# [327]	validation_0-mae:8.14065	validation_1-mae:30.44024
# [328]	validation_0-mae:8.12094	validation_1-mae:30.43756
# [329]	validation_0-mae:8.10306	validation_1-mae:30.43384
# [330]	validation_0-mae:8.08671	validation_1-mae:30.42622
# [331]	validation_0-mae:8.06815	validation_1-mae:30.42072
# [332]	validation_0-mae:8.04642	validation_1-mae:30.41767
# [333]	validation_0-mae:8.02903	validation_1-mae:30.41189
# [334]	validation_0-mae:8.01114	validation_1-mae:30.40685
# [335]	validation_0-mae:7.99364	validation_1-mae:30.40142
# [336]	validation_0-mae:7.97665	validation_1-mae:30.39856
# [337]	validation_0-mae:7.96037	validation_1-mae:30.39146
# [338]	validation_0-mae:7.94413	validation_1-mae:30.38364
# [339]	validation_0-mae:7.92688	validation_1-mae:30.37858
# [340]	validation_0-mae:7.91113	validation_1-mae:30.37198
# [341]	validation_0-mae:7.89442	validation_1-mae:30.36729
# [342]	validation_0-mae:7.87818	validation_1-mae:30.36470
# [343]	validation_0-mae:7.86119	validation_1-mae:30.35977
# [344]	validation_0-mae:7.84609	validation_1-mae:30.35634
# [345]	validation_0-mae:7.83106	validation_1-mae:30.35135
# [346]	validation_0-mae:7.81658	validation_1-mae:30.34801
# [347]	validation_0-mae:7.80154	validation_1-mae:30.34898
# [348]	validation_0-mae:7.78577	validation_1-mae:30.34466
# [349]	validation_0-mae:7.77253	validation_1-mae:30.33671
# [350]	validation_0-mae:7.75885	validation_1-mae:30.33296
# [351]	validation_0-mae:7.74598	validation_1-mae:30.32986
# [352]	validation_0-mae:7.73074	validation_1-mae:30.32550
# [353]	validation_0-mae:7.71534	validation_1-mae:30.31877
# [354]	validation_0-mae:7.70253	validation_1-mae:30.31392
# [355]	validation_0-mae:7.68792	validation_1-mae:30.31019
# [356]	validation_0-mae:7.67527	validation_1-mae:30.30546
# [357]	validation_0-mae:7.66303	validation_1-mae:30.30137
# [358]	validation_0-mae:7.65079	validation_1-mae:30.29674
# [359]	validation_0-mae:7.63629	validation_1-mae:30.29302
# [360]	validation_0-mae:7.62453	validation_1-mae:30.28909
# [361]	validation_0-mae:7.61256	validation_1-mae:30.28463
# [362]	validation_0-mae:7.60096	validation_1-mae:30.28080
# [363]	validation_0-mae:7.58473	validation_1-mae:30.28564
# [364]	validation_0-mae:7.57282	validation_1-mae:30.28136
# [365]	validation_0-mae:7.56130	validation_1-mae:30.27770
# [366]	validation_0-mae:7.54726	validation_1-mae:30.27441
# [367]	validation_0-mae:7.53573	validation_1-mae:30.27029
# [368]	validation_0-mae:7.51996	validation_1-mae:30.27516
# [369]	validation_0-mae:7.50894	validation_1-mae:30.27173
# [370]	validation_0-mae:7.49801	validation_1-mae:30.26778
# [371]	validation_0-mae:7.48447	validation_1-mae:30.26602
# [372]	validation_0-mae:7.47134	validation_1-mae:30.26518
# [373]	validation_0-mae:7.45590	validation_1-mae:30.27053
# [374]	validation_0-mae:7.44272	validation_1-mae:30.26888
# [375]	validation_0-mae:7.42809	validation_1-mae:30.25961
# [376]	validation_0-mae:7.41615	validation_1-mae:30.25523
# [377]	validation_0-mae:7.40454	validation_1-mae:30.24698
# [378]	validation_0-mae:7.39279	validation_1-mae:30.24596
# [379]	validation_0-mae:7.38149	validation_1-mae:30.23960
# [380]	validation_0-mae:7.36668	validation_1-mae:30.23322
# [381]	validation_0-mae:7.35299	validation_1-mae:30.22743
# [382]	validation_0-mae:7.33939	validation_1-mae:30.21849
# [383]	validation_0-mae:7.32622	validation_1-mae:30.21278
# [384]	validation_0-mae:7.31318	validation_1-mae:30.20158
# [385]	validation_0-mae:7.30215	validation_1-mae:30.19320
# [386]	validation_0-mae:7.29315	validation_1-mae:30.18840
# [387]	validation_0-mae:7.28078	validation_1-mae:30.19148
# [388]	validation_0-mae:7.27224	validation_1-mae:30.19018
# [389]	validation_0-mae:7.26377	validation_1-mae:30.18892
# [390]	validation_0-mae:7.25198	validation_1-mae:30.18761
# [391]	validation_0-mae:7.24350	validation_1-mae:30.18451
# [392]	validation_0-mae:7.23285	validation_1-mae:30.17894
# [393]	validation_0-mae:7.22391	validation_1-mae:30.17580
# [394]	validation_0-mae:7.21597	validation_1-mae:30.17480
# [395]	validation_0-mae:7.20154	validation_1-mae:30.17686
# [396]	validation_0-mae:7.19159	validation_1-mae:30.17539
# [397]	validation_0-mae:7.17751	validation_1-mae:30.17743
# [398]	validation_0-mae:7.16847	validation_1-mae:30.17348
# [399]	validation_0-mae:7.15658	validation_1-mae:30.17536
# [400]	validation_0-mae:7.14485	validation_1-mae:30.17068
# [401]	validation_0-mae:7.13626	validation_1-mae:30.16876
# [402]	validation_0-mae:7.12651	validation_1-mae:30.16250
# [403]	validation_0-mae:7.11757	validation_1-mae:30.15889
# [404]	validation_0-mae:7.10947	validation_1-mae:30.15663
# [405]	validation_0-mae:7.10155	validation_1-mae:30.15440
# [406]	validation_0-mae:7.09368	validation_1-mae:30.15219
# [407]	validation_0-mae:7.08548	validation_1-mae:30.14868
# [408]	validation_0-mae:7.07807	validation_1-mae:30.14769
# [409]	validation_0-mae:7.06994	validation_1-mae:30.14418
# [410]	validation_0-mae:7.06077	validation_1-mae:30.14190
# [411]	validation_0-mae:7.05351	validation_1-mae:30.14101
# [412]	validation_0-mae:7.04054	validation_1-mae:30.14307
# [413]	validation_0-mae:7.03246	validation_1-mae:30.13973
# [414]	validation_0-mae:7.01977	validation_1-mae:30.14178
# [415]	validation_0-mae:7.01107	validation_1-mae:30.14094
# [416]	validation_0-mae:7.00312	validation_1-mae:30.13772
# [417]	validation_0-mae:6.99378	validation_1-mae:30.14173
# [418]	validation_0-mae:6.98640	validation_1-mae:30.13986
# [419]	validation_0-mae:6.97890	validation_1-mae:30.13869
# [420]	validation_0-mae:6.96965	validation_1-mae:30.14275
# [421]	validation_0-mae:6.96262	validation_1-mae:30.14226
# [422]	validation_0-mae:6.95522	validation_1-mae:30.14121
# [423]	validation_0-mae:6.94607	validation_1-mae:30.14534
# [424]	validation_0-mae:6.93914	validation_1-mae:30.14495
# [425]	validation_0-mae:6.93153	validation_1-mae:30.14222
# [426]	validation_0-mae:6.92417	validation_1-mae:30.14133
# [427]	validation_0-mae:6.91512	validation_1-mae:30.14554
# [428]	validation_0-mae:6.90820	validation_1-mae:30.14529
# [429]	validation_0-mae:6.90145	validation_1-mae:30.14505
# [430]	validation_0-mae:6.89358	validation_1-mae:30.14274
# [431]	validation_0-mae:6.88426	validation_1-mae:30.13830
# [432]	validation_0-mae:6.87761	validation_1-mae:30.13816
# [433]	validation_0-mae:6.86831	validation_1-mae:30.13381
# [434]	validation_0-mae:6.85956	validation_1-mae:30.13056
# [435]	validation_0-mae:6.85300	validation_1-mae:30.13051
# [436]	validation_0-mae:6.84548	validation_1-mae:30.12680
# [437]	validation_0-mae:6.83857	validation_1-mae:30.12240
# [438]	validation_0-mae:6.82963	validation_1-mae:30.12190
# [439]	validation_0-mae:6.82116	validation_1-mae:30.11883
# [440]	validation_0-mae:6.81256	validation_1-mae:30.11838
# [441]	validation_0-mae:6.80531	validation_1-mae:30.11679
# [442]	validation_0-mae:6.79861	validation_1-mae:30.11260
# [443]	validation_0-mae:6.79243	validation_1-mae:30.11285
# [444]	validation_0-mae:6.78393	validation_1-mae:30.11220
# [445]	validation_0-mae:6.77736	validation_1-mae:30.10994
# [446]	validation_0-mae:6.77091	validation_1-mae:30.10592
# [447]	validation_0-mae:6.76399	validation_1-mae:30.10516
# [448]	validation_0-mae:6.75605	validation_1-mae:30.10463
# [449]	validation_0-mae:6.74965	validation_1-mae:30.10506
# [450]	validation_0-mae:6.74329	validation_1-mae:30.10120
# [451]	validation_0-mae:6.73682	validation_1-mae:30.10106
# [452]	validation_0-mae:6.72869	validation_1-mae:30.09954
# [453]	validation_0-mae:6.72241	validation_1-mae:30.10008
# [454]	validation_0-mae:6.71613	validation_1-mae:30.09637
# [455]	validation_0-mae:6.70843	validation_1-mae:30.09606
# [456]	validation_0-mae:6.70217	validation_1-mae:30.09413
# [457]	validation_0-mae:6.69106	validation_1-mae:30.09230
# [458]	validation_0-mae:6.68447	validation_1-mae:30.09191
# [459]	validation_0-mae:6.67690	validation_1-mae:30.09169
# [460]	validation_0-mae:6.66589	validation_1-mae:30.08997
# [461]	validation_0-mae:6.65890	validation_1-mae:30.09378
# [462]	validation_0-mae:6.65263	validation_1-mae:30.09407
# [463]	validation_0-mae:6.64646	validation_1-mae:30.09067
# [464]	validation_0-mae:6.63940	validation_1-mae:30.08675
# [465]	validation_0-mae:6.62849	validation_1-mae:30.08520
# [466]	validation_0-mae:6.62121	validation_1-mae:30.08805
# [467]	validation_0-mae:6.61506	validation_1-mae:30.08846
# [468]	validation_0-mae:6.60434	validation_1-mae:30.08701
# [469]	validation_0-mae:6.59703	validation_1-mae:30.08703
# [470]	validation_0-mae:6.59029	validation_1-mae:30.09097
# [471]	validation_0-mae:6.57981	validation_1-mae:30.08961
# [472]	validation_0-mae:6.57348	validation_1-mae:30.08853
# [473]	validation_0-mae:6.56757	validation_1-mae:30.08569
# [474]	validation_0-mae:6.55837	validation_1-mae:30.08915
# [475]	validation_0-mae:6.54788	validation_1-mae:30.08791
# [476]	validation_0-mae:6.53875	validation_1-mae:30.09137
# [477]	validation_0-mae:6.53204	validation_1-mae:30.09539
# [478]	validation_0-mae:6.52356	validation_1-mae:30.10085
# [479]	validation_0-mae:6.51326	validation_1-mae:30.09969
# [480]	validation_0-mae:6.50709	validation_1-mae:30.09880
# [481]	validation_0-mae:6.49805	validation_1-mae:30.10235
# [482]	validation_0-mae:6.48966	validation_1-mae:30.10779
# [483]	validation_0-mae:6.47930	validation_1-mae:30.10671
# [484]	validation_0-mae:6.47034	validation_1-mae:30.11029
# [485]	validation_0-mae:6.46488	validation_1-mae:30.10924
# [486]	validation_0-mae:6.45508	validation_1-mae:30.11073
# [487]	validation_0-mae:6.44700	validation_1-mae:30.11395
# [488]	validation_0-mae:6.43889	validation_1-mae:30.11956
# [489]	validation_0-mae:6.42867	validation_1-mae:30.11859
# [490]	validation_0-mae:6.41897	validation_1-mae:30.12016
# [491]	validation_0-mae:6.40544	validation_1-mae:30.12348
# [492]	validation_0-mae:6.39671	validation_1-mae:30.12976
# [493]	validation_0-mae:6.38856	validation_1-mae:30.13510
# [494]	validation_0-mae:6.37993	validation_1-mae:30.14130
# [495]	validation_0-mae:6.36888	validation_1-mae:30.13917
# [496]	validation_0-mae:6.35458	validation_1-mae:30.14056
# [497]	validation_0-mae:6.34907	validation_1-mae:30.13821
# [498]	validation_0-mae:6.33812	validation_1-mae:30.13612
# [499]	validation_0-mae:6.32918	validation_1-mae:30.13904
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.01, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=500, n_jobs=0, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=None)

# %% [markdown]
# **Developer's note**: You might see slight increase in MAE. This XGBRegressor optimizes squared loss by default. There isn't support for MAE since gradient boosting (may) require non-zero second order derivatives. Need to confirm

# %%
predictions = reg.predict(X_test)

# %%
test_df = test_df.reset_index().drop('index', axis=1)
test_df['predictions'] = pd.Series(predictions)

# %%
plt.rcParams.update({'figure.figsize': (17, 3), 'figure.dpi':300})
fig, ax = plt.subplots()
sns.lineplot(data=weekly_orders.tail(50), x='week', y='num_orders')
sns.lineplot(data=test_df, x='week', y='predictions')
plt.grid(linestyle='-', linewidth=0.3)
ax.tick_params(axis='x', rotation=90)

# %%
test_df
# Out:
#           week  order_count_7_day  order_count_30_day  label  predictions
# 0   2019-06-03                 84                 416    100    66.390121
# 1   2019-06-10                100                 428     76    92.323196
# 2   2019-06-17                 76                 433    102   110.203674
# 3   2019-06-24                102                 414     94    86.136459
# 4   2019-07-01                 94                 389     94    88.356873
# 5   2019-07-08                 94                 366     40    87.550453
# 6   2019-07-15                 40                 377    114    79.235619
# 7   2019-07-22                114                 381    108    86.746536
# 8   2019-07-29                108                 393    102    74.123482
# 9   2019-08-05                102                 406     41    90.902115
# 10  2019-08-26                  0                 186      3    23.627138
# 11  2019-09-02                  3                  77     91    35.422333
# 12  2019-09-30                  0                  94     80    10.508982
# 13  2019-10-28                  0                  86     25    15.233247
# 14  2019-11-04                 25                  60     65    36.589420
# 15  2019-11-25                  0                  90     24    15.233247
# 16  2019-12-02                 24                  97     97    30.266638

# %% [markdown]
# ### Case 2: Prophet

# %%
# !pip3 install pystan==2.19.1.1
# !pip3 install fbprophet==0.7.1

# %%
from fbprophet import Prophet

# %%
data = df[['week', 'label']]
data.columns = ['ds', 'y']
train_df_prophet = data[data['ds'] < '2019-06-01']
test_df_prophet = data[data['ds'] >= '2019-06-01']

# %%
data = df[['week', 'label']]
data.columns = ['ds', 'y']

# %%
data.sample(2)
# Out:
#              ds    y
# 122  2018-06-11  103
# 129  2018-07-30   54

# %%
res = []
for idx in range(173, 190):
    train_df_prophet = data[data.index < idx]
    test_df_prophet = data[data.index == idx]
    m = Prophet(weekly_seasonality=False, daily_seasonality=False)
    m.fit(train_df_prophet)
    prophet_predictions = m.predict(test_df_prophet)
    prophet_predictions['ds'] = prophet_predictions['ds'].apply(lambda x: x.strftime('%Y-%m-%d'))
    result = test_df_prophet.merge(prophet_predictions[['ds', 'yhat']], on='ds')
    res.append(result)

# %%
test_df_prophet = pd.concat(res)

# %%
plt.rcParams.update({'figure.figsize': (17, 3), 'figure.dpi':300})
fig, ax = plt.subplots()
sns.lineplot(data=weekly_orders.tail(50), x='week', y='num_orders')
sns.lineplot(data=test_df_prophet, x='ds', y='yhat')
plt.grid(linestyle='-', linewidth=0.3)
ax.tick_params(axis='x', rotation=90)
